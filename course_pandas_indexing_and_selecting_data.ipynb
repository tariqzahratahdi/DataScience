# %%
# importing pandas
import pandas as pd

# csv file location
url = 'https://raw.githubusercontent.com/tariqzahratahdi/DataScience/refs/heads/main/datasets/fortune500.csv'

# making data frame from csv file
data = pd.read_csv(url, index_col = 'company')

# %% [markdown]
# # Indexing and Selecting Data
#
# Indexing in Pandas means simply selecting particular rows and columns of data from a DataFrame.
#
# Indexing could mean selecting all the rows and some of the columns, some of the rows and all of the columns, or some of each of the rows and columns.
#
# Indexing can also be known as subset selection.
#
# Some common methods and attributes for viewing and selecting data in a Pandas DataFrame include:
#
# * `head(n=5)` : Displays the first n rows of a DataFrame.
# * `tail(n=5)` : Displays the last n rows of a DataFrame.
# * `loc` : Accesses a group of rows and columns by labels or a boolean array.
# * `iloc` : Accesses a group of rows and columns by integer indices.
# * `columns` : Lists the column labels of the DataFrame.
# * `['A']` : Selects the column named `A` from the DataFrame.
#
# **Example**

# %%
# selecting data
data_selection = data.head()

data_selection
# Out:
#                           rank  revenues  revenue_change  profits  assets  \
# company
# Walmart                      1    485873             0.8  13643.0  198825
# State Grid                   2    315199            -4.4   9571.3  489838
# Sinopec Group                3    267518            -9.1   1257.9  310726
# China National Petroleum     4    262573           -12.3   1867.5  585619
# Toyota Motor                 5    254694             7.7  16899.3  437575
#
#                           profit_change                  ceo  \
# company
# Walmart                            -7.2  C. Douglas McMillon
# State Grid                         -6.2              Kou Wei
# Sinopec Group                     -65.0            Wang Yupu
# China National Petroleum          -73.7        Zhang Jianhua
# Toyota Motor                      -12.3          Akio Toyoda
#
#                                           industry                  sector  \
# company
# Walmart                      General Merchandisers               Retailing
# State Grid                               Utilities                  Energy
# Sinopec Group                   Petroleum Refining                  Energy
# China National Petroleum        Petroleum Refining                  Energy
# Toyota Motor              Motor Vehicles and Parts  Motor Vehicles & Parts
#
#                           previous_rank country
# company
# Walmart                               1     USA
# State Grid                            2   China
# Sinopec Group                         4   China
# China National Petroleum              3   China
# Toyota Motor                          8   Japan

# %%
# selecting data
data_selection = data.tail()

data_selection
# Out:
#                                 rank  revenues  revenue_change  profits  \
# company
# Teva Pharmaceutical Industries   496     21903            11.5    329.0
# New China Life Insurance         497     21796           -13.3    743.9
# Wm. Morrison Supermarkets        498     21741           -11.3    406.4
# TUI                              499     21655            -5.5   1151.7
# AutoNation                       500     21609             3.6    430.5
#
#                                 assets  profit_change                 ceo  \
# company
# Teva Pharmaceutical Industries   92890          -79.3   Yitzhak Peterburg
# New China Life Insurance        100609          -45.6            Wan Feng
# Wm. Morrison Supermarkets        11630           20.4      David T. Potts
# TUI                              16247          195.5   Friedrich Joussen
# AutoNation                       10060           -2.7  Michael J. Jackson
#
#                                                       industry  \
# company
# Teva Pharmaceutical Industries                 Pharmaceuticals
# New China Life Insurance        Insurance: Life Health (stock)
# Wm. Morrison Supermarkets                 Food and Drug Stores
# TUI                                            Travel Services
# AutoNation                                 Specialty Retailers
#
#                                             sector  previous_rank  country
# company
# Teva Pharmaceutical Industries         Health Care              0   Israel
# New China Life Insurance                Financials            427    China
# Wm. Morrison Supermarkets       Food & Drug Stores            437  Britain
# TUI                              Business Services            467  Germany
# AutoNation                               Retailing              0      USA

# %% [markdown]
# # Indexing a DataFrame using indexing operator `[ ]`
#
# Indexing operator refers to the square brackets `[ ]` following an object.
#
# In order to select a single column, we simply put the name of the column in-between the brackets
#
# Note: use a column name other than the index column.
#
# **Example**

# %%
# selecting columns by indexing operator
data_selection = data['rank']

data_selection
# Out:
# company
# Walmart                             1
# State Grid                          2
# Sinopec Group                       3
# China National Petroleum            4
# Toyota Motor                        5
#                                  ...
# Teva Pharmaceutical Industries    496
# New China Life Insurance          497
# Wm. Morrison Supermarkets         498
# TUI                               499
# AutoNation                        500
# Name: rank, Length: 500, dtype: int64

# %% [markdown]
# Note that the instruction (`data['rank']`) will return a `Series` and not a `DataFrame`.

# %%
print(type(data_selection))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# To convert it to a `DataFrame`, we can enclose the single column inside the `[]` operator. The syntax will be as follows:

# %%
data_selection = data[['rank']]

print(type(data_selection))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## Select multiple columns

# %%
# selecting columns by indexing operator
data_selection = data[['rank', 'revenues']]

data_selection
# Out:
#                                 rank  revenues
# company
# Walmart                            1    485873
# State Grid                         2    315199
# Sinopec Group                      3    267518
# China National Petroleum           4    262573
# Toyota Motor                       5    254694
# ...                              ...       ...
# Teva Pharmaceutical Industries   496     21903
# New China Life Insurance         497     21796
# Wm. Morrison Supermarkets        498     21741
# TUI                              499     21655
# AutoNation                       500     21609
#
# [500 rows x 2 columns]

# %% [markdown]
# # Indexing a DataFrame using indexer attributes
#
# Pandas provides some special indexer attributes that explicitly expose certain indexing schemes.
#
# These are not functional methods, but attributes that expose a particular slicing interface to the data in the `Series`.
#
# ## The **`loc`** attribute
#
# The **`loc`** attribute in Pandas is a property of a DataFrame used for label-based indexing and selection.
#
# It allows accessing a group of rows and columns by using their labels (i.e., row and column names), rather than their integer positions.
#
# This attribute allows indexing and slicing that always references the explicit index.
#
# It selects data in a different way than just the indexing operator.
#
# It can select subsets of rows or columns.
#
# It can also simultaneously select subsets of rows and columns.
#
# **Label-based:**
#
# `loc` primarily operates on the labels of the index and columns. When slicing with `loc`, both the start and stop labels are inclusive, unlike standard Python slicing.
#
# **Flexible input:**
#
# It can accept various inputs for selecting rows and columns, including:
# * A single label: `df.loc['row_label', 'col_label']`
# * A list or array of labels: `df.loc[['row1', 'row2'], ['colA', 'colB']]`
# * A slice object with labels: `df.loc['start_row':'end_row', 'start_col':'end_col']`
# * A boolean array: `df.loc[df['column'] > 5]`
#
# **Example:** select a single row with label Toyota Motor:

# %%
# select a single row
data_selection = data.loc['Toyota Motor']

# show dataframe
data_selection
# Out:
# rank                                     5
# revenues                            254694
# revenue_change                         7.7
# profits                            16899.3
# assets                              437575
# profit_change                        -12.3
# ceo                            Akio Toyoda
# industry          Motor Vehicles and Parts
# sector              Motor Vehicles & Parts
# previous_rank                            8
# country                              Japan
# Name: Toyota Motor, dtype: object

# %% [markdown]
# **Example:** select rows with labels Toyota Motor and Volkswagen:

# %%
# select rows with labels Toyota Motor and Volkswagen
data_selection = data.loc[['Toyota Motor', 'Volkswagen']]

# show dataframe
data_selection
# Out:
#               rank  revenues  revenue_change  profits  assets  profit_change  \
# company
# Toyota Motor     5    254694             7.7  16899.3  437575          -12.3
# Volkswagen       6    240264             1.5   5937.3  432116            NaN
#
#                           ceo                  industry  \
# company
# Toyota Motor      Akio Toyoda  Motor Vehicles and Parts
# Volkswagen    Matthias Muller  Motor Vehicles and Parts
#
#                               sector  previous_rank  country
# company
# Toyota Motor  Motor Vehicles & Parts              8    Japan
# Volkswagen    Motor Vehicles & Parts              7  Germany

# %% [markdown]
# **Example:** select rows with labels Toyota Motor and Volkswagen, and column with label revenues:

# %%
# select rows with labels Toyota Motor and Volkswagen, and column with label revenues
data_selection = data.loc[['Toyota Motor', 'Volkswagen'], 'revenues']

# show dataframe
data_selection
# Out:
# company
# Toyota Motor    254694
# Volkswagen      240264
# Name: revenues, dtype: int64

# %% [markdown]
# **Example:** select row with label Toyota Motor, and columns with labels revenues and profits:

# %%
# select row with label Toyota Motor, and columns with labels revenues and profits
data_selection = data.loc['Toyota Motor', ['revenues', 'profits']]

# show dataframe
data_selection
# Out:
# revenues     254694
# profits     16899.3
# Name: Toyota Motor, dtype: object

# %% [markdown]
# **Example:** select rows with labels Toyota Motor and Volkswagen, and columns with labels revenues and profits:

# %%
# select rows with labels Toyota Motor and Volkswagen,
# and columns with labels revenues and profits
rows_labels = ['Toyota Motor', 'Volkswagen']
columns_labels = ['revenues', 'profits']
data_selection = data.loc[rows_labels, columns_labels]

# show dataframe
data_selection
# Out:
#               revenues  profits
# company
# Toyota Motor    254694  16899.3
# Volkswagen      240264   5937.3

# %% [markdown]
# **Example:** select a slice of contiguous rows with labels ranging from Walmart to Toyota Motor, and a slice of contiguous columns with labels ranging from revenues to profit_change:

# %%
# select a slice of contiguous rows
# with labels ranging from Walmart to Toyota Motor
# and a slice of contiguous columns
# with labels ranging from revenues to profit_change
data_selection = data.loc['Walmart':'Toyota Motor', 'revenues':'profit_change']

# show dataframe
data_selection
# Out:
#                           revenues  revenue_change  profits  assets  \
# company
# Walmart                     485873             0.8  13643.0  198825
# State Grid                  315199            -4.4   9571.3  489838
# Sinopec Group               267518            -9.1   1257.9  310726
# China National Petroleum    262573           -12.3   1867.5  585619
# Toyota Motor                254694             7.7  16899.3  437575
#
#                           profit_change
# company
# Walmart                            -7.2
# State Grid                         -6.2
# Sinopec Group                     -65.0
# China National Petroleum          -73.7
# Toyota Motor                      -12.3

# %% [markdown]
# # The **`iloc`** attribute
#
# The **`iloc`** attribute allows indexing and slicing that always references the implicit Python-style index.
#
# This attribute is used to select rows from a DataFrame.
#
# In order to select a row using `iloc`, we need to specify the position of this row.

# %%
# select row by iloc method
data_selection = data.iloc[0]

# show dataframe
data_selection
# Out:
# rank                                  1
# revenues                         485873
# revenue_change                      0.8
# profits                         13643.0
# assets                           198825
# profit_change                      -7.2
# ceo                 C. Douglas McMillon
# industry          General Merchandisers
# sector                        Retailing
# previous_rank                         1
# country                             USA
# Name: Walmart, dtype: object

# %% [markdown]
# **Example:** select rows with indices 0, 1 and 2, and columns with indices 1 and 2:

# %%
# select rows with indices 0, 1 and 2, and columns with indices 1 and 3
data_selection = data.iloc[[0, 1, 2], [1, 3]]

# show dataframe
data_selection
# Out:
#                revenues  profits
# company
# Walmart          485873  13643.0
# State Grid       315199   9571.3
# Sinopec Group    267518   1257.9
