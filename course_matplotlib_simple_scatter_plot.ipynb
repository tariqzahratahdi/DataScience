# %% [markdown]
# <a href="https://colab.research.google.com/github/tariqzahratahdi/DataScience/blob/main/course_matplotlib_simple_scatter_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Scatter plot
#
# The simple scatter plot represents the points individually with a dot, circle, or other shape, instead of joining points by line segments.
#
# **Example**

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8-whitegrid')

# setting data
x = np.linspace(0, 10, 30)

# setting figure
plt.plot(x, np.sin(x), 'o')
plt.plot(x, np.cos(x), '.')

# plotting figure
plt.show()

# %% [markdown]
# The third argument in the `plot()` function call is a character that represents the type of symbol used for the plotting.
#
# # Scatter plots with **`plt.scatter()`**
#
# A second method of creating scatter plots is the `plt.scatter()` function, which can be used very similarly to the `plt.plot()` function.
#
# **Example**

# %%
plt.scatter(x, np.sin(x), marker='o')

# plotting figure
plt.show()

# %% [markdown]
# The primary difference of `plt.scatter()` from `plt.plot()` is that it can be used to create scatter plots where the properties of each individual point (size, face color, edge color, etc.) can be individually controlled or mapped to data.
#
# Let’s show this by creating a random scatter plot with points of many colors and sizes.
#
# In order to better see the overlapping results, we’ll also use the `alpha` keyword to adjust the transparency level.

# %%
# setting data
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

# setting figure
plt.scatter(x, y, c=colors, s=sizes, alpha=0.3, cmap='viridis')
plt.colorbar() # show color scale

# plotting figure
plt.show()

# %% [markdown]
# The unit of the marker size is point² (typographic point is 1/72 inch).
#
# Colormap is a set of colors arranged in a specific order, it is used to visually represent data.

# %% [markdown]
# <br><br>
# ![course-matplotlib-simple-scatter-plot-01.png](data:image/png;base64,...)
# <br><br>
