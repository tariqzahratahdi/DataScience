# %% [markdown]
# # Data Visualization
#
# In the following we will use a dataset containing data about the population of countries.

# %%
import pandas as pd

# csv file location
url = 'https://raw.githubusercontent.com/tariqzahratahdi/DataScience/refs/heads/main/datasets/population.csv'

# making dataframe from csv file
data = pd.read_csv(url)

# show dataframe
data
# Out:
#             country    year    population
# 0             China  2020.0  1.439324e+09
# 1             China  2019.0  1.433784e+09
# 2             China  2018.0  1.427648e+09
# 3             China  2017.0  1.421022e+09
# 4             China  2016.0  1.414049e+09
# ...             ...     ...           ...
# 4180  United States  1965.0  1.997337e+08
# 4181  United States  1960.0  1.867206e+08
# 4182  United States  1955.0  1.716853e+08
# 4183          India  1960.0  4.505477e+08
# 4184          India  1955.0  4.098806e+08
#
# [4185 rows x 3 columns]

# %% [markdown]
# ### Making a Pivot Table
#
# **Drop null values:**

# %%
# drop null values
data.dropna(inplace=True)

# show dataframe
data
# Out:
#             country    year    population
# 0             China  2020.0  1.439324e+09
# 1             China  2019.0  1.433784e+09
# 2             China  2018.0  1.427648e+09
# 3             China  2017.0  1.421022e+09
# 4             China  2016.0  1.414049e+09
# ...             ...     ...           ...
# 4180  United States  1965.0  1.997337e+08
# 4181  United States  1960.0  1.867206e+08
# 4182  United States  1955.0  1.716853e+08
# 4183          India  1960.0  4.505477e+08
# 4184          India  1955.0  4.098806e+08
#
# [4178 rows x 3 columns]

# %% [markdown]
# **Make a pivot table:**

# %%
# make a pivot table
data_pivot = data.pivot(index='year', columns='country', values='population')

# show dataframe
data_pivot
# Out:
# country  Afghanistan    Albania     Algeria  American Samoa  Andorra  \
# year
# 1955.0     8270991.0  1419994.0   9774283.0         19754.0   9232.0
# 1960.0     8996973.0  1636090.0  11057863.0         20123.0  13411.0
# 1965.0     9956320.0  1896171.0  12550885.0         23672.0  18549.0
# 1970.0    11173642.0  2150707.0  14464985.0         27363.0  24276.0
# 1975.0    12689160.0  2411732.0  16607707.0         30052.0  30705.0
# 1980.0    13356511.0  2682690.0  19221665.0         32646.0  36067.0
# 1985.0    11938208.0  2969672.0  22431502.0         39519.0  44600.0
# 1990.0    12412308.0  3286073.0  25758869.0         47347.0  54509.0
# 1995.0    18110657.0  3112936.0  28757785.0         53161.0  63850.0
# 2000.0    20779953.0  3129243.0  31042235.0         57821.0  65390.0
# 2005.0    25654277.0  3086810.0  33149724.0         59562.0  78867.0
# 2010.0    29185507.0  2948023.0  35977455.0         56079.0  84449.0
# ...

# %% [markdown]
# **Select data:**

# %%
# filter data
data_filter = data['country'].isin(['Mauritania', 'Morocco', 'Algeria', 'Tunisia', 'Libya'])

# select data
data_selected = data[data_filter]

# show dataframe
data_selected
# Out:
#          country    year  population
# 2000  Mauritania  2020.0   4649658.0
# 2001  Mauritania  2019.0   4525696.0
# 2066  Mauritania  2018.0   4403313.0
# 2067  Mauritania  2017.0   4282570.0
# 2068  Mauritania  2016.0   4163533.0
# ...          ...     ...         ...
# 3996     Algeria  1975.0  16607707.0
# 3997     Algeria  1970.0  14464985.0
# 4057     Algeria  1965.0  12550885.0
# 4058     Algeria  1960.0  11057863.0
# 4059     Algeria  1955.0   9774283.0
#
# [90 rows x 3 columns]

# %% [markdown]
# **Make a pivot table**

# %%
# make a pivot table
data_pivot = data_selected.pivot(index='year', columns='country', values='population')

# show dataframe
data_pivot
# Out:
# country     Algeria      Libya  Mauritania     Morocco     Tunisia
# year
# 1955.0    9774283.0  1245358.0    738299.0  10502666.0   3943540.0
# 1960.0   11057863.0  1448417.0    850384.0  12328532.0   4178236.0
# 1965.0   12550885.0  1733306.0    985910.0  14230163.0   4547941.0
# 1970.0   14464985.0  2133526.0   1146780.0  16004731.0   5063809.0
# 1975.0   16607707.0  2645139.0   1330598.0  17796164.0   5656914.0
# 1980.0   19221665.0  3219466.0   1540640.0  19990012.0   6374039.0
# 1985.0   22431502.0  3873781.0   1780030.0  22499110.0   7329594.0
# 1990.0   25758869.0  4436661.0   2034346.0  24807462.0   8242496.0
# 1995.0   28757785.0  4948798.0   2313630.0  26994250.0   9125398.0
# 2000.0   31042235.0  5357891.0   2630219.0  28793679.0   9708350.0
# 2005.0   33149724.0  5798614.0   3024194.0  30455561.0  10106771.0
# 2010.0   35977455.0  6197663.0   3494195.0  32343389.0  10635244.0
# 2015.0   39728025.0  6418315.0   4046301.0  34663603.0  11179949.0
# ...

# %% [markdown]
# ## Data Visualization
#
# ### Line Plot

# %%
# line plot
data_pivot.plot(kind='line', xlabel='Year', ylabel='Population', title='Population Evolution')
# Out:
# <Axes: title={'center': 'Population Evolution'}, xlabel='Year', ylabel='Population'>

# %% [markdown]
# ### Bar Plot
#
# **Single Bar Plot**
#
# Select only one year:

# %%
# select only one year (2020)
data_pivot_filter = data_pivot.index.isin([2020])
data_pivot_selected = data_pivot[data_pivot_filter]

# show dataframe
data_pivot_selected
# Out:
# country     Algeria      Libya  Mauritania     Morocco     Tunisia
# year
# 2020.0   43851044.0  6871292.0   4649658.0  36910560.0  11818619.0

# %% [markdown]
# Transpose dataframe: columns to rows and vice versa:

# %%
# transpose dataframe: columns to rows and vice versa
data_pivot_selected = data_pivot_selected.T

# show dataframe
data_pivot_selected
# Out:
# year            2020.0
# country
# Algeria     43851044.0
# Libya        6871292.0
# Mauritania   4649658.0
# Morocco     36910560.0
# Tunisia     11818619.0

# %% [markdown]
# Show bar plot:

# %%
# bar plot
data_pivot_selected.plot(kind='bar')
# Out:
# <Axes: xlabel='country'>

# %% [markdown]
# **Bar plot grouped by n variables**
#
# Select a few years:

# %%
# select few years
data_pivot_filter = data_pivot.index.isin([1980, 1990, 2000, 2010, 2020])
data_pivot_selected = data_pivot[data_pivot_filter]

# show dataframe
data_pivot_selected
# Out:
# country     Algeria      Libya  Mauritania     Morocco     Tunisia
# year
# 1980.0   19221665.0  3219466.0   1540640.0  19990012.0   6374039.0
# 1990.0   25758869.0  4436661.0   2034346.0  24807462.0   8242496.0
# 2000.0   31042235.0  5357891.0   2630219.0  28793679.0   9708350.0
# 2010.0   35977455.0  6197663.0   3494195.0  32343389.0  10635244.0
# 2020.0   43851044.0  6871292.0   4649658.0  36910560.0  11818619.0

# %% [markdown]
# Show bar plot:

# %%
# bar plot
data_pivot_selected.plot(kind='bar', xlabel='Year', ylabel='Population', title='Population Evolution')
# Out:
# <Axes: title={'center': 'Population Evolution'}, xlabel='Year', ylabel='Population'>

# %% [markdown]
# ### Pie Chart
#
# Selecting only one year:

# %%
# select only one year (2020)
data_pivot_filter = data_pivot.index.isin([2020])
data_pivot_selected = data_pivot[data_pivot_filter]

# transpose dataframe: columns to rows and vice versa
data_pivot_selected = data_pivot_selected.T

# show dataframe
data_pivot_selected
# Out:
# year            2020.0
# country
# Algeria     43851044.0
# Libya        6871292.0
# Mauritania   4649658.0
# Morocco     36910560.0
# Tunisia     11818619.0

# %% [markdown]
# Rename column:

# %%
# rename column
data_pivot_selected.rename(columns={2020:'2020'}, inplace=True)

# show dataframe
data_pivot_selected
# Out:
# year              2020
# country
# Algeria     43851044.0
# Libya        6871292.0
# Mauritania   4649658.0
# Morocco     36910560.0
# Tunisia     11818619.0

# %% [markdown]
# Show pie chart:

# %%
# pie chart
data_pivot_selected.plot(kind='pie', y='2020', ylabel='Year 2020', title='Population Proportions')
# Out:
# <Axes: title={'center': 'Population Proportions'}, ylabel='Year 2020'>

# %% [markdown]
# ### Box Plot
#
# **Single Box Plot**
#
# Select only one country:

# %%
# select only one country
data_pivot_selected = data_pivot['Morocco']

# show dataframe
data_pivot_selected
# Out:
# year
# 1955.0    10502666.0
# 1960.0    12328532.0
# 1965.0    14230163.0
# 1970.0    16004731.0
# 1975.0    17796164.0
# 1980.0    19990012.0
# 1985.0    22499110.0
# 1990.0    24807462.0
# 1995.0    26994250.0
# 2000.0    28793679.0
# 2005.0    30455561.0
# 2010.0    32343389.0
# 2015.0    34663603.0
# 2016.0    35126283.0
# 2017.0    35581255.0
# 2018.0    36029093.0
# 2019.0    36471769.0
# 2020.0    36910560.0
# Name: Morocco, dtype: float64

# %% [markdown]
# Show box plot:

# %%
# show box plot
data_pivot_selected.plot(kind='box', ylabel='Population', title='Population Distribution')
# Out:
# <Axes: title={'center': 'Population Distribution'}, ylabel='Population'>

# %% [markdown]
# **Multiple Box Plots**

# %%
# show multiple box plots
data_pivot.plot(kind='box', ylabel='Population', title='Population Distribution by Country')
# Out:
# <Axes: title={'center': 'Population Distribution by Country'}, ylabel='Population'>

# %% [markdown]
# ### Histogram
#
# **Single Histogram**
#
# Show histogram:

# %%
# show histogram
data_pivot_selected.plot(kind='hist', xlabel='Population', title='Population Frequency Distribution')
# Out:
# <Axes: title={'center': 'Population Frequency Distribution'}, xlabel='Population', ylabel='Frequency'>

# %% [markdown]
# Select countries:

# %%
# select countries
data_pivot_selected = data_pivot[['Morocco', 'Algeria']]

# show dataframe
data_pivot_selected
# Out:
# country     Morocco     Algeria
# year
# 1955.0   10502666.0   9774283.0
# 1960.0   12328532.0  11057863.0
# 1965.0   14230163.0  12550885.0
# 1970.0   16004731.0  14464985.0
# 1975.0   17796164.0  16607707.0
# 1980.0   19990012.0  19221665.0
# 1985.0   22499110.0  22431502.0
# 1990.0   24807462.0  25758869.0
# 1995.0   26994250.0  28757785.0
# 2000.0   28793679.0  31042235.0
# 2005.0   30455561.0  33149724.0
# 2010.0   32343389.0  35977455.0
# 2015.0   34663603.0  39728025.0
# 2016.0   35126283.0  40551392.0
# 2017.0   35581255.0  41389189.0
# 2018.0   36029093.0  42228408.0
# 2019.0   36471769.0  43053054.0
# 2020.0   36910560.0  43851044.0

# %% [markdown]
# Show multiple histograms:

# %%
data_pivot_selected.plot(kind='hist', xlabel='Population', title='Population Frequency Distribution')
# Out:
# <Axes: title={'center': 'Population Frequency Distribution'}, xlabel='Population', ylabel='Frequency'>

# %% [markdown]
# ### Scatter Plot
#
# Select data:

# %%
# show dataframe
data_selected
# Out:
#          country    year  population
# 2000  Mauritania  2020.0   4649658.0
# 2001  Mauritania  2019.0   4525696.0
# 2066  Mauritania  2018.0   4403313.0
# 2067  Mauritania  2017.0   4282570.0
# 2068  Mauritania  2016.0   4163533.0
# ...          ...     ...         ...
# 3996     Algeria  1975.0  16607707.0
# 3997     Algeria  1970.0  14464985.0
# 4057     Algeria  1965.0  12550885.0
# 4058     Algeria  1960.0  11057863.0
# 4059     Algeria  1955.0   9774283.0
#
# [90 rows x 3 columns]

# %% [markdown]
# Show scatter plot:

# %%
# show scatter plot
data_selected.plot(kind='scatter', x='year', y='population')
# Out:
# <Axes: xlabel='year', ylabel='population'>
